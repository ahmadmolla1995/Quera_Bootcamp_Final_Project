# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Load Requirements from other google drive

# %%
# !gdown --id 1-AlW7oNJHaqi3xk_9dWHUS52Dzl_FmFW
# !gdown --id 1-8TsrqTRFP-q9TM-6HinhO0ZVXFHq9TB
# !gdown --id 1upN9GkZb7QAFMyWMVrRPTdeSEY_bGXJM
# !gdown --id 1-GchNC0UAUalYVRfr-qf08LPawpVs3O7
# !gdown --id 1--QVtOtL26q8MNu6JLBCKRIGmh3FyI5t
# !gdown --id 1gyk5b5QzgjCt1df-xTVqYVCzbikqy34o
# !gdown --id 1Wi0u9NSUPHo9SQVhvDBMv-i4HysEUcQb
# !gdown --id 1-030IdL3oQhqC_JSkZUPGQwkWux74bV4
# !gdown --id 1T3VVrZW5rjQ3fED8w1ruMWbuiZVrqSBU
# !gdown --id 1LnBYLXk01gpgNdaOQZJtGJWDEky2RTvX
# !gdown --id 1-It8CDsmD6bXIqzyoSshZxbFoHkI4X1u
# !gdown --id 1-KMIWWR1ewn5i7tBpV4PUwd__em2oesl
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-AlW7oNJHaqi3xk_9dWHUS52Dzl_FmFW
# From (redirected): https://drive.google.com/uc?id=1-AlW7oNJHaqi3xk_9dWHUS52Dzl_FmFW&confirm=t&uuid=29c59b5c-ff71-4d37-9191-3ba7e120962c
# To: /content/train_data.csv
# 100% 635M/635M [00:06<00:00, 101MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-8TsrqTRFP-q9TM-6HinhO0ZVXFHq9TB
# To: /content/test_data.csv
# 100% 15.6M/15.6M [00:00<00:00, 18.2MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1upN9GkZb7QAFMyWMVrRPTdeSEY_bGXJM
# To: /content/title_brand.csv
# 100% 97.3M/97.3M [00:02<00:00, 38.7MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-GchNC0UAUalYVRfr-qf08LPawpVs3O7
# To: /content/train_data_sample.csv
# 100% 98.1M/98.1M [00:01<00:00, 59.7MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1--QVtOtL26q8MNu6JLBCKRIGmh3FyI5t
# To: /content/test_data_spell_checked.csv
# 100% 12.0M/12.0M [00:00<00:00, 126MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1gyk5b5QzgjCt1df-xTVqYVCzbikqy34o
# To: /content/train_data_sample_spell_checked.csv
# 100% 97.9M/97.9M [00:00<00:00, 119MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Wi0u9NSUPHo9SQVhvDBMv-i4HysEUcQb
# From (redirected): https://drive.google.com/uc?id=1Wi0u9NSUPHo9SQVhvDBMv-i4HysEUcQb&confirm=t&uuid=43d9b562-fb06-4453-8fbe-a7fdec68ce68
# To: /content/train_data_larger_sample.csv
# 100% 379M/379M [00:07<00:00, 53.5MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1-030IdL3oQhqC_JSkZUPGQwkWux74bV4
# To: /content/test_data_clean.csv
# 100% 18.5M/18.5M [00:00<00:00, 116MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1T3VVrZW5rjQ3fED8w1ruMWbuiZVrqSBU
# From (redirected): https://drive.google.com/uc?id=1T3VVrZW5rjQ3fED8w1ruMWbuiZVrqSBU&confirm=t&uuid=e0253284-87f7-443f-b1dd-07108045e811
# To: /content/train_data_sample_spell_checked_clean.csv
# 100% 155M/155M [00:01<00:00, 133MB/s]

# %%
import os
import shutil
import pandas as pd
import numpy as np

# Define the folder path
folder_path = '/content/drive/MyDrive/bootcamp/data'

# Create the folder if it doesn't already exist
os.makedirs(folder_path, exist_ok=True)

# %%
shutil.move('/content/train_data.csv', f'{folder_path}/train_data.csv')
shutil.move('/content/test_data.csv', f'{folder_path}/test_data.csv')
shutil.move('/content/test_data_clean.csv', f'{folder_path}/test_data_clean.csv')
shutil.move('/content/test_data_spell_checked.csv', f'{folder_path}/test_data_spell_checked.csv')
shutil.move('/content/title_brand.csv', f'{folder_path}/title_brand.csv')
shutil.move('/content/train_data_larger_sample.csv', f'{folder_path}/train_data_larger_sample.csv')
shutil.move('/content/train_data_sample.csv', f'{folder_path}/train_data_sample.csv')
shutil.move('/content/train_data_sample_spell_checked.csv', f'{folder_path}/train_data_sample_spell_checked.csv')
shutil.move('/content/train_data_sample_spell_checked_clean.csv', f'{folder_path}/train_data_sample_spell_checked_clean.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_sample_spell_checked_clean.csv'

# %%
train_data_path = f'{folder_path}/train_data.csv'
test_data_path = f'{folder_path}/test_data.csv'

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
# Out:
# <ipython-input-9-e081c316124a>:4: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
train_data.head()
# Out:
#    overall vote  verified  reviewTime      reviewerID        asin style  \
# 0        2  NaN     False  2016-11-11   A2OSUEZJIN7BI  0511189877   NaN
# 1        5  NaN      True  2016-06-06  A2NETQRG6JHIG7  0511189877   NaN
# 2        4  NaN      True  2016-03-10  A12JHGROAX49G7  0511189877   NaN
# 3        5  NaN      True  2016-01-14  A1KV65E2TMMG6F  0511189877   NaN
# 4        5  NaN      True  2016-10-20  A280POPEWI0NSA  0594459451   NaN
#
#     reviewerName                                         reviewText  \
# 0          Chris  I have an older URC-WR7 remote and thought thi...
# 1   Qrysta White  First time I've EVER had a remote that needed ...
# 2        Linwood  Got them and only 2 of them worked. company ca...
# 3  Dane Williams  I got tired of the remote being on the wrong s...
# 4    Kristina H.  After purchasing cheap cords from another webs...
#
#                                summary  unixReviewTime
# 0                         Cannot Learn      1478822400
# 1  zero programming needed!  Miracle!?      1465171200
# 2        Works Good and programs easy.      1457568000
# 3                   Same as TWC remote      1452729600
# 4                    Good Quality Cord      1476921600

# %%
train_data.shape
# Out:
# (838944, 11)

# %%
train_data['reviewText'][0]
# Out:
# "I have an older URC-WR7 remote and thought this would be an upgrade (and because TWC stuck me with it), but this one fails where the other one didn't.  The old remote could go head to head and learn.  I have 2 different Blu Ray players (LG & Panasonic) and this one fails on both.  It cannot learn buttons.  The biggest problem is in streaming when I need to hit the blue, red, yellow, green buttons.  These cannot work either of them, so I have to pull out the remote for that one setting.  I don't know why they give you multiple code methods but no learning."

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838944 entries, 0 to 838943
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         838944 non-null  int64
#  1   vote            191468 non-null  object
#  2   verified        838944 non-null  bool
#  3   reviewTime      838944 non-null  object
#  4   reviewerID      838944 non-null  object
#  5   asin            838944 non-null  object
#  6   style           490613 non-null  object
#  7   reviewerName    838717 non-null  object
#  8   reviewText      838944 non-null  object
#  9   summary         838868 non-null  object
#  10  unixReviewTime  838944 non-null  int64
# dtypes: bool(1), int64(2), object(8)
# memory usage: 64.8+ MB

# %%
train_data['reviewText'] = train_data['reviewText'].str.lower().str.strip()
train_data['summary'] = train_data['summary'].str.lower().str.strip()

test_data['reviewText'] = test_data['reviewText'].str.lower().str.strip()
test_data['summary'] = test_data['summary'].str.lower().str.strip()

# %%
import re

# Define a regex pattern that removes all punctuation except for ?! and .
pattern = r'[^a-zA-Z0-9\s?!\.]'

# Apply this to the reviewText and summary columns, with a check for string type
train_data['reviewText'] = train_data['reviewText'].apply(lambda x: re.sub(pattern, '', x) if isinstance(x, str) else x)
train_data['summary'] = train_data['summary'].apply(lambda x: re.sub(pattern, '', x) if isinstance(x, str) else x)

# Assuming you have a similar structure for test_data
test_data['reviewText'] = test_data['reviewText'].apply(lambda x: re.sub(pattern, '', x) if isinstance(x, str) else x)
test_data['summary'] = test_data['summary'].apply(lambda x: re.sub(pattern, '', x) if isinstance(x, str) else x)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)

# %%
from textblob import TextBlob

def correct_spelling(text):
    return str(TextBlob(text).correct())

train_data['reviewText'] = train_data['reviewText'].apply(correct_spelling)
train_data['summary'] = train_data['summary'].apply(correct_spelling)

test_data['reviewText'] = test_data['reviewText'].apply(correct_spelling)
test_data['summary'] = test_data['summary'].apply(correct_spelling)

# %%
# !pip install symspellpy
# Out:
# Collecting symspellpy
#   Downloading symspellpy-6.7.8-py3-none-any.whl.metadata (3.9 kB)
# Collecting editdistpy>=0.1.3 (from symspellpy)
#   Downloading editdistpy-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Downloading symspellpy-6.7.8-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.1 MB/s eta 0:00:00
# Downloading editdistpy-0.1.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: editdistpy, symspellpy
# Successfully installed editdistpy-0.1.5 symspellpy-6.7.8

# %%
import pkg_resources
from symspellpy import SymSpell, Verbosity

# %%
dictionary_path = pkg_resources.resource_filename("symspellpy", "frequency_dictionary_en_82_765.txt")

sym_spell = SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
sym_spell.load_dictionary(dictionary_path, term_index=0, count_index=1)

input_term = "memebers"

suggestions = sym_spell.lookup(input_term, Verbosity.CLOSEST, max_edit_distance=2)
for suggestion in suggestions:
    print(suggestion)
# Out:
# members, 1, 226656153

# %%
from operator import attrgetter

dictionary_cache = set()


def find_nearest_word_in_dict(word):
    word = word.lower()

    if word in dictionary_cache:
        return word

    suggestions = sym_spell.lookup(word, Verbosity.CLOSEST, max_edit_distance=2, include_unknown=True)
    suggestions = sorted(suggestions, key=attrgetter('distance'))

    min_distance = suggestions[0].distance
    nearest_word = max([s for s in suggestions if s.distance == min_distance], key=attrgetter('count'))

    dictionary_cache.add(nearest_word.term)

    return nearest_word.term

# %%
sample_sentence = train_data['reviewText'][9]
sample_sentence
# Out:
# 'brand name adapter this is just like the one you got when you bought your nook. i would always recommend using a designated adapter. the charging cable is a whole different story but the adapter defiantly use the designated charger.'

# %%
tokens = sample_sentence.split()
tokens
# Out:
# ['brand',
#  'name',
#  'adapter',
#  'this',
#  'is',
#  'just',
#  'like',
#  'the',
#  'one',
#  'you',
#  'got',
#  'when',
#  'you',
#  'bought',
#  'your',
#  'nook.',
#  'i',
#  'would',
#  'always',
#  'recommend',
#  'using',
#  'a',
#  'designated',
#  'adapter.',
#  'the',
#  'charging',
#  'cable',
#  'is',
#  'a',
#  'whole',
#  'different',
#  'story',
#  'but',
#  'the',
#  'adapter',
#  'defiantly',
#  'use',
#  'the',
#  'designated',
#  'charger.']

# %%
corrected_tokens = []

for t in tokens:
    nearest = find_nearest_word_in_dict(t)
    corrected_tokens.append(nearest)

# %% [markdown]
# ### Mis-spelling correction example

# %%
for t, c in zip(tokens, corrected_tokens):
    print(t, c)
# Out:
# brand brand
# name name
# adapter adapter
# this this
# is is
# just just
# like like
# the the
# one one
# you you
# got got
# when when
# you you
# bought bought
# your your
# nook. nook
# i i
# would would
# always always
# recommend recommend
# using using
# a a
# designated designated
# adapter. adapter
# the the
# charging charging
# cable cable
# is is
# a a
# whole whole
# different different
# story story
# but but
# the the
# adapter adapter
# defiantly defiantly
# use use
# the the
# designated designated
# charger. charger

# %%
def correct_spelling_symspell(sentence):
    tokens = sentence.split()
    corrected_tokens = list(map(find_nearest_word_in_dict, tokens))

    return ' '.join(corrected_tokens)

# %%
corrected_sentence = correct_spelling_symspell(sample_sentence)

print('main sentence: \n{}'.format(sample_sentence))
print('corrected sentence: \n{}'.format(corrected_sentence))
# Out:
# main sentence:
# brand name adapter this is just like the one you got when you bought your nook. i would always recommend using a designated adapter. the charging cable is a whole different story but the adapter defiantly use the designated charger.
# corrected sentence:
# brand name adapter this is just like the one you got when you bought your nook i would always recommend using a designated adapter the charging cable is a whole different story but the adapter defiantly use the designated charger

# %% [markdown]
# ### Removing Stop words from review text and summaries

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)

# %%
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag, word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
pos_tag(word_tokenize("John's very big idea isn't all that bad."))
# Out:
# [('John', 'NNP'),
#  ("'s", 'POS'),
#  ('very', 'RB'),
#  ('big', 'JJ'),
#  ('idea', 'NN'),
#  ('is', 'VBZ'),
#  ("n't", 'RB'),
#  ('all', 'PDT'),
#  ('that', 'DT'),
#  ('bad', 'JJ'),
#  ('.', '.')]

# %%
stop_words = set(stopwords.words('english'))


def remove_stop_words(text):
    tokens = word_tokenize(text.lower())
    word_tag = pos_tag(tokens)

    tokens = [w[0] for w in word_tag if w[0] not in stop_words or w[1] in ['VBZ', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'RB', 'RBR', 'RBS']]

    return ' '.join(tokens)

# %%
print('main sentence: \n{}\n'.format(sample_sentence))
print('sentence after removing stop words:\n{}'.format(remove_stop_words(sample_sentence)))
# Out:
# main sentence:
# brand name adapter this is just like the one you got when you bought your nook. i would always recommend using a designated adapter. the charging cable is a whole different story but the adapter defiantly use the designated charger.
#
# sentence after removing stop words:
# brand name adapter is just like one got bought nook . would always recommend using designated adapter . charging cable is whole different story adapter defiantly use designated charger .

# %%
train_data['overall'].value_counts()
# Out:
# overall
# 5    461485
# 4    156514
# 1     82950
# 3     81239
# 2     56756
# Name: count, dtype: int64

# %%
train_data_sample = train_data.sample(frac=0.2)
train_data_sample.head()
# Out:
#         overall vote  verified  reviewTime      reviewerID        asin  \
# 691413        5    5      True  2017-05-05  A2WM4XD9GQW4D9  B01EK7TEL4
# 128283        1  NaN      True  2017-02-03   AOKQ5KDS3LRRK  B007IL6OR2
# 306502        5  NaN      True  2016-02-03   AT4MNYYZWM907  B00LSZTCO6
# 449923        4    4      True  2017-02-01   AN17Z00NUJW0V  B00XI87KV8
# 763986        5  NaN      True  2016-08-29  A2OFBWUFQOMEOP  B00AW54YWS
#
#                                            style    reviewerName  \
# 691413   {'Style:': ' Sound Bar with Subwoofer'}  Pascal Renault
# 128283  {'Package Type:': ' Standard Packaging'}            Alex
# 306502                     {'Color:': ' Silver'}       Adam Hume
# 449923             {'Style:': ' 50-Inch Tripod'}    Kate Mahoney
# 763986                                       NaN  Anthony Miller
#
#                                                reviewText  \
# 691413  fit in a tight spot no room for receiver and s...
# 128283  product is defective connection only works on ...
# 306502  amazing product.  i bought a different bluetoo...
# 449923  for the price this is a great little tripod an...
# 763986  i have had this camcorder for about 2 years an...
#
#                                                   summary  unixReviewTime
# 691413                           impressive for the price      1493942400
# 128283              only half works got a defective item.      1486080000
# 306502  amazing product. i bought a different bluetoot...      1454457600
# 449923  great starterlight use tripod for audio video ...      1485907200
# 763986  the battery still holds a good charge and last...      1472428800

# %%
train_data_sample['overall'].value_counts()
# Out:
# overall
# 5    92457
# 4    31354
# 1    16479
# 3    16203
# 2    11296
# Name: count, dtype: int64

# %%
train_data_sample['reviewText'] = train_data_sample['reviewText'].apply(remove_stop_words)

# %%
test_data.head()
# Out:
#    vote  verified  reviewTime      reviewerID        asin  \
# 0   NaN      True  2018-06-04  A20GGWE66JW9X2  B006Z394GM
# 1   NaN      True  2018-02-18   ARYJWXHEYHG9M  B005BE058W
# 2   NaN      True  2018-01-20  A10LHZ7WFZ7HLL  B01DA0YCNC
# 3   NaN      True  2018-06-25  A11VN8EOHNLP72  B00FBJ4KYC
# 4   3.0      True  2016-08-17  A194Y8P8TVT7P9  B00P7G82TS
#
#                                   style     reviewerName  \
# 0                {'Color:': ' FPS01-C'}    Brian C Toner
# 1  {'Size:': ' 1000W', 'Style:': ' G2'}            Snake
# 2                                   NaN  Amazon Customer
# 3                                   NaN      Jeremy Bray
# 4                                   NaN             Mark
#
#                                           reviewText  \
# 0  the name and description of this device are mi...
# 1  one of the molex connectors on the power suppl...
# 2  remote constantly disconnects roku player free...
# 3  i purchased this 4 year protection plan for a ...
# 4  i bought one of these and have regretted it ev...
#
#                                              summary  unixReviewTime
# 0  the prize for most useless invention of all ti...      1528070400
# 1                             melted molex connector      1518912000
# 2                             bricked on the regular      1516406400
# 3                                      do not buy!!!      1529884800
# 4                                nightmare  dont buy      1471392000

# %%
test_data['reviewText'] = test_data['reviewText'].apply(remove_stop_words)

# %%
train_data_sample.to_csv('train_data_sample.csv')
shutil.move('/content/train_data_sample.csv', f'{folder_path}/train_data_sample.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_sample.csv'

# %% [markdown]
# ### Spell checking after removing stop words in Train data sample

# %%
train_data_sample_path = f'{folder_path}/train_data_sample.csv'
train_data_sample = pd.read_csv(train_data_sample_path)
# Out:
# <ipython-input-29-e5d03b372bc2>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data_sample = pd.read_csv(train_data_sample_path)

# %%
train_data_sample.head()
# Out:
#    Unnamed: 0  overall vote  verified  reviewTime      reviewerID        asin  \
# 0       44867        4  NaN      True  2016-12-27  A2SGDGD3R8YAR3  B0015HOFZI
# 1      514712        3  NaN      True  2016-09-15  A31XQAQ6OAK63H  B013QJ0W8Q
# 2      321051        1  NaN      True  2016-11-11  A1VNJUKIW0DROT  B00MSTG93S
# 3      643355        5    2     False  2016-11-12   A194OCP49BPKN  B01BY7YOAY
# 4      470838        5  NaN      True  2016-05-03   A41130X01BBBT  B00ZI7IS2W
#
#                               style                    reviewerName  \
# 0                               NaN         Sean&#039;s Amazon site
# 1  {'Color:': ' Advanced Car Kits'}                         Heather
# 2                               NaN  Luis Alberto Carranza Gonzalez
# 3                               NaN                           Jimbo
# 4        {'Color:': ' 8CH+8Camera'}                       Gabby1947
#
#                                           reviewText  \
# 0  good price money . really like turntable works...
# 1  didnt realize wouldnt be able have radio have ...
# 2  bought march 24 i travel europe october 10 dev...
# 3  hi first got denon avrs510bt receiver hooked p...
# 4  good system works great . installed disabled o...
#
#                                              summary  unixReviewTime
# 0  good turntable for a reasonble price.  softwar...      1482796800
# 1         okay for music not so much for phone calls      1473897600
# 2              it failed 7 months after i bought it.      1478822400
# 3                 yamaha rxv381bl vs denon avrs510bt      1478908800
# 4                          great product great price      1462233600

# %%
train_data_sample.drop('Unnamed: 0', axis=1, inplace=True)

# %%
train_data_sample['reviewText'] = train_data_sample['reviewText'].apply(correct_spelling_symspell)

# %%
test_data['reviewText'] = test_data['reviewText'].apply(correct_spelling_symspell)

# %%
import shutil

train_data_sample.to_csv('train_data_sample_spell_checked.csv')
shutil.move('/content/train_data_sample_spell_checked.csv', f'{folder_path}/train_data_sample_spell_checked.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_sample_spell_checked.csv'

# %%
train_data_sample_spell_checked_path = f'{folder_path}/train_data_sample_spell_checked.csv'
train_data_sample_spell_checked = pd.read_csv(train_data_sample_spell_checked_path)

train_data_sample_spell_checked.head()
# Out:
# <ipython-input-35-f699217def39>:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data_sample_spell_checked = pd.read_csv(train_data_sample_spell_checked_path)
#    Unnamed: 0  overall vote  verified  reviewTime      reviewerID        asin  \
# 0           0        4  NaN      True  2016-12-27  A2SGDGD3R8YAR3  B0015HOFZI
# 1           1        3  NaN      True  2016-09-15  A31XQAQ6OAK63H  B013QJ0W8Q
# 2           2        1  NaN      True  2016-11-11  A1VNJUKIW0DROT  B00MSTG93S
# 3           3        5    2     False  2016-11-12   A194OCP49BPKN  B01BY7YOAY
# 4           4        5  NaN      True  2016-05-03   A41130X01BBBT  B00ZI7IS2W
#
#                               style                    reviewerName  \
# 0                               NaN         Sean&#039;s Amazon site
# 1  {'Color:': ' Advanced Car Kits'}                         Heather
# 2                               NaN  Luis Alberto Carranza Gonzalez
# 3                               NaN                           Jimbo
# 4        {'Color:': ' 8CH+8Camera'}                       Gabby1947
#
#                                           reviewText  \
# 0  good price money a really like turntable works...
# 1  didst realize wouldn't be able have radio have...
# 2  bought march of i travel europe october of dev...
# 3  hi first got devon avrs510bt receiver hooked p...
# 4  good system works great a installed disabled o...
#
#                                              summary  unixReviewTime
# 0  good turntable for a reasonble price.  softwar...      1482796800
# 1         okay for music not so much for phone calls      1473897600
# 2              it failed 7 months after i bought it.      1478822400
# 3                 yamaha rxv381bl vs denon avrs510bt      1478908800
# 4                          great product great price      1462233600

# %%
train_data_sample_spell_checked.drop('Unnamed: 0', axis=1, inplace=True)

# %%
import shutil

test_data.to_csv('test_data_spell_checked.csv')
shutil.move('/content/test_data_spell_checked.csv', f'{folder_path}/test_data_spell_checked.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/test_data_spell_checked.csv'

# %%
test_data_spell_checked_path = f'{folder_path}/test_data_spell_checked.csv'
test_data_spell_checked = pd.read_csv(test_data_spell_checked_path)

test_data_spell_checked.head()
# Out:
#    Unnamed: 0  vote  verified  reviewTime      reviewerID        asin  \
# 0           0   NaN      True  2018-06-04  A20GGWE66JW9X2  B006Z394GM
# 1           1   NaN      True  2018-02-18   ARYJWXHEYHG9M  B005BE058W
# 2           2   NaN      True  2018-01-20  A10LHZ7WFZ7HLL  B01DA0YCNC
# 3           3   NaN      True  2018-06-25  A11VN8EOHNLP72  B00FBJ4KYC
# 4           4   3.0      True  2016-08-17  A194Y8P8TVT7P9  B00P7G82TS
#
#                                   style     reviewerName  \
# 0                {'Color:': ' FPS01-C'}    Brian C Toner
# 1  {'Size:': ' 1000W', 'Style:': ' G2'}            Snake
# 2                                   NaN  Amazon Customer
# 3                                   NaN      Jeremy Bray
# 4                                   NaN             Mark
#
#                                           reviewText  \
# 0  name description device are misleading a is su...
# 1  one rolex connectors power supply started melt...
# 2  remote constantly disconnects roku player free...
# 3  purchased a year protection plan security syst...
# 4  bought one have regretted ever since a gas rec...
#
#                                              summary  unixReviewTime
# 0  the prize for most useless invention of all ti...      1528070400
# 1                             melted molex connector      1518912000
# 2                             bricked on the regular      1516406400
# 3                                      do not buy!!!      1529884800
# 4                                nightmare  dont buy      1471392000

# %%
test_data_spell_checked.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ### Finding Similary words in two separate dataframes

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.5)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
from sklearn.metrics.pairwise import cosine_similarity
import gensim.downloader as api
from tqdm import tqdm

# Load a simpler pre-trained word embedding model (GloVe or Word2Vec)
word_vectors = api.load("glove-wiki-gigaword-50")  # Can replace with "word2vec-google-news-300"

# Define target word embeddings for "guarantee" and "warranty"
target_words = ["guarantee", "warranty"]
target_embeddings = {word: word_vectors[word] for word in target_words}

# Quick keyword-based filter
keywords = set(target_words)

# Function to classify based on keyword presence and cosine similarity
def classify_review_simple(review, threshold=0.8):
    # Step 1: Quick filter - Check if any keyword exists in the review
    if any(keyword in review.lower() for keyword in keywords):
        words = review.lower().split()
        for word in words:
            if word in word_vectors:
                # Calculate similarity to target words
                word_embedding = word_vectors[word].reshape(1, -1)
                for target_word, target_embedding in target_embeddings.items():
                    similarity = cosine_similarity(word_embedding, target_embedding.reshape(1, -1))[0][0]
                    if similarity >= threshold:
                        return "guarantee"
    return "no guarantee"

# Apply classification with progress tracking
tqdm.pandas(desc="Classifying reviews")  # Set up tqdm with description

# Classify all reviews with progress bar
train_data_sample_spell_checked['classification'] = train_data_sample_spell_checked['reviewText'].progress_apply(classify_review_simple)

# Split into DataFrames based on classification
guarantee_reviews_train = train_data_sample_spell_checked[train_data_sample_spell_checked['classification'] == "guarantee"]
no_guarantee_reviews_train = train_data_sample_spell_checked[train_data_sample_spell_checked['classification'] == "no guarantee"]
# Out:
# Classifying reviews: 100%|██████████| 167789/167789 [05:58<00:00, 468.49it/s]

# %%
import ace_tools as tools

tools.display_dataframe_to_user(name="Guarantee Reviews in Train Data", dataframe=guarantee_reviews_train)
tools.display_dataframe_to_user(name="No Guarantee Reviews in Train Data", dataframe=no_guarantee_reviews_train)

# %%
train_data_sample_spell_checked.head()
# Out:
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0        4  NaN      True  2016-12-27  A2SGDGD3R8YAR3  B0015HOFZI
# 1        3  NaN      True  2016-09-15  A31XQAQ6OAK63H  B013QJ0W8Q
# 2        1  NaN      True  2016-11-11  A1VNJUKIW0DROT  B00MSTG93S
# 3        5    2     False  2016-11-12   A194OCP49BPKN  B01BY7YOAY
# 4        5  NaN      True  2016-05-03   A41130X01BBBT  B00ZI7IS2W
#
#                               style                    reviewerName  \
# 0                               NaN         Sean&#039;s Amazon site
# 1  {'Color:': ' Advanced Car Kits'}                         Heather
# 2                               NaN  Luis Alberto Carranza Gonzalez
# 3                               NaN                           Jimbo
# 4        {'Color:': ' 8CH+8Camera'}                       Gabby1947
#
#                                           reviewText  \
# 0  good price money a really like turntable works...
# 1  didst realize wouldn't be able have radio have...
# 2  bought march of i travel europe october of dev...
# 3  hi first got devon avrs510bt receiver hooked p...
# 4  good system works great a installed disabled o...
#
#                                              summary  unixReviewTime  \
# 0  good turntable for a reasonble price.  softwar...      1482796800
# 1         okay for music not so much for phone calls      1473897600
# 2              it failed 7 months after i bought it.      1478822400
# 3                 yamaha rxv381bl vs denon avrs510bt      1478908800
# 4                          great product great price      1462233600
#
#   classification
# 0   no guarantee
# 1   no guarantee
# 2      guarantee
# 3   no guarantee
# 4   no guarantee

# %% [markdown]
# ### Loading Brand and title data

# %%
# !gdown --id 1I9aPAvvYgQWdHGKtnd7IeTGXpx8vOm4h
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1I9aPAvvYgQWdHGKtnd7IeTGXpx8vOm4h
# To: /content/title_brand.csv
# 100% 97.3M/97.3M [00:03<00:00, 30.5MB/s]

# %%
shutil.move('/content/title_brand.csv', f'{folder_path}/title_brand.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/title_brand.csv'

# %%
title_brand_path = f'{folder_path}/title_brand.csv'
title_brand = pd.read_csv(title_brand_path)

title_brand.head()
# Out:
#          asin                                              title  \
# 0  0011300000  Genuine Geovision 1 Channel 3rd Party NVR IP S...
# 1  0043396828  Books "Handbook of Astronomical Image Processi...
# 2  0060009810                                     One Hot Summer
# 3  0060219602  Hurray for Hattie Rabbit: Story and pictures (...
# 4  0060786817                     sex.lies.murder.fame.: A Novel
#
#                                           brand
# 0                                     GeoVision
# 1                                  33 Books Co.
# 2  Visit Amazon's Carolina Garcia Aguilera Page
# 3           Visit Amazon's Dick Gackenbach Page
# 4              Visit Amazon's Lolita Files Page

# %%
title_brand[title_brand['asin'] == 'B0015HOFZI']
# Out:
#               asin                                 title brand
# 125368  B0015HOFZI  Sony PSLX300USB USB Stereo Turntable  Sony

# %%
train_data_sample_spell_checked = train_data_sample_spell_checked.merge(title_brand, on='asin', how='inner')
train_data_sample_spell_checked.head()
# Out:
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0        4  NaN      True  2016-12-27  A2SGDGD3R8YAR3  B0015HOFZI
# 1        3  NaN      True  2016-09-15  A31XQAQ6OAK63H  B013QJ0W8Q
# 2        1  NaN      True  2016-11-11  A1VNJUKIW0DROT  B00MSTG93S
# 3        5    2     False  2016-11-12   A194OCP49BPKN  B01BY7YOAY
# 4        5  NaN      True  2016-05-03   A41130X01BBBT  B00ZI7IS2W
#
#                               style                    reviewerName  \
# 0                               NaN         Sean&#039;s Amazon site
# 1  {'Color:': ' Advanced Car Kits'}                         Heather
# 2                               NaN  Luis Alberto Carranza Gonzalez
# 3                               NaN                           Jimbo
# 4        {'Color:': ' 8CH+8Camera'}                       Gabby1947
#
#                                           reviewText  \
# 0  good price money a really like turntable works...
# 1  didst realize wouldn't be able have radio have...
# 2  bought march of i travel europe october of dev...
# 3  hi first got devon avrs510bt receiver hooked p...
# 4  good system works great a installed disabled o...
#
#                                              summary  unixReviewTime  \
# 0  good turntable for a reasonble price.  softwar...      1482796800
# 1         okay for music not so much for phone calls      1473897600
# 2              it failed 7 months after i bought it.      1478822400
# 3                 yamaha rxv381bl vs denon avrs510bt      1478908800
# 4                          great product great price      1462233600
#
#                                                title         brand
# 0               Sony PSLX300USB USB Stereo Turntable          Sony
# 1  TaoTronics Bluetooth Receiver/Car Kit, Portabl...    TaoTronics
# 2  BESTEK Power Step Down 220V to 110V Voltage Co...        BESTEK
# 3                  Yamaha RX-V381BL Receiver (Black)  Yamaha Audio
# 4  Funlux Waterproof 8 Channel 960H HDMI DVR  Hom...        Funlux

# %%
def embed_product_info_in_comment(record):
    return 'my idea about product with id \'{}\' with name {} from brand {} is: {}'.format(record['asin'], record['title'], record['brand'], record['reviewText'])

# %%
result = embed_product_info_in_comment(train_data_sample_spell_checked.iloc[0])
result
# Out:
# "my idea about product with id 'B0015HOFZI' with name Sony PSLX300USB USB Stereo Turntable from brand Sony is: good price money a really like turntable works well connected ria jacks sounder a comes sony sound forge software is little bit complicated a was able figure record vinyl records laptop burn cd a was fairly easy process a recording onto cd was plenty loud did find recording doesn't always start beginning track a am still experimenting report further software future a software prompts settings make sure set line get best recording a has been years since used turntable did not immediately see belt is wrapped around bottom turntable simply pulling belt capstan allows hook turntable a visual directions were not good a"

# %%
train_data_sample_spell_checked['reviewText'] = train_data_sample_spell_checked.apply(embed_product_info_in_comment, axis=1)

# %%
train_data_sample_spell_checked['reviewText'].head()
# Out:
# 0    my idea about product with id 'B0015HOFZI' wit...
# 1    my idea about product with id 'B013QJ0W8Q' wit...
# 2    my idea about product with id 'B00MSTG93S' wit...
# 3    my idea about product with id 'B01BY7YOAY' wit...
# 4    my idea about product with id 'B00ZI7IS2W' wit...
# Name: reviewText, dtype: object

# %%
import shutil

train_data_sample_spell_checked.to_csv('train_data_sample_spell_checked_clean.csv')
shutil.move('/content/train_data_sample_spell_checked_clean.csv', f'{folder_path}/train_data_sample_spell_checked_clean.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_sample_spell_checked_clean.csv'

# %% [markdown]
# ### Loading cleaned data

# %%
train_data_clean = pd.read_csv(f'{folder_path}/train_data_balance.csv')
# Out:
# <ipython-input-35-1a90834f2218>:1: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
train_data_clean.shape
# Out:
# (100000, 13)

# %%
train_data_clean['overall'].value_counts()
# Out:
# overall
# 1    20000
# 2    20000
# 3    20000
# 4    20000
# 5    20000
# Name: count, dtype: int64

# %%
train_data_clean = train_data_clean.sample(frac=1)
train_data_clean.shape
# Out:
# (100000, 13)

# %% [markdown]
# ### Loading Bert Model for training on dataset

# %%
import torch
import tarfile
import tensorflow as tf
from transformers import BertTokenizer, TFBertForSequenceClassification
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objects as go
from wordcloud import WordCloud, STOPWORDS
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
x_train = train_data_clean['reviewText']
y_train = train_data_clean['overall']

x_train.shape, y_train.shape
# Out:
# ((100000,), (100000,))

# %%
x_train.head()
# Out:
# 77832    my idea about product with id 'B00ZR4NH9U' wit...
# 35974    my idea about product with id 'B016KBV9SE' wit...
# 31861    my idea about product with id 'B00PG5ZYKK' wit...
# 53370    my idea about product with id 'B00BS4FDWW' wit...
# 16332    my idea about product with id 'B00134BZP6' wit...
# Name: reviewText, dtype: object

# %%
y_train.head()
# Out:
# 77832    4
# 35974    2
# 31861    2
# 53370    3
# 16332    1
# Name: overall, dtype: int64

# %%
y_train.max(), y_train.min()
# Out:
# (5, 1)

# %%
y_train = y_train - 1
y_train.head()
# Out:
# 77832    3
# 35974    1
# 31861    1
# 53370    2
# 16332    0
# Name: overall, dtype: int64

# %%
test_data_spell_checked = test_data_spell_checked.merge(title_brand, on='asin', how='inner')
test_data_spell_checked.head()

# %%
test_data_spell_checked['reviewText'] = test_data_spell_checked.apply(embed_product_info_in_comment, axis=1)
test_data_spell_checked.head()
# Out:
#    vote  verified  reviewTime      reviewerID        asin  \
# 0   NaN      True  2018-06-04  A20GGWE66JW9X2  B006Z394GM
# 1   NaN      True  2018-02-18   ARYJWXHEYHG9M  B005BE058W
# 2   NaN      True  2018-01-20  A10LHZ7WFZ7HLL  B01DA0YCNC
# 3   NaN      True  2018-06-25  A11VN8EOHNLP72  B00FBJ4KYC
# 4   3.0      True  2016-08-17  A194Y8P8TVT7P9  B00P7G82TS
#
#                                   style     reviewerName  \
# 0                {'Color:': ' FPS01-C'}    Brian C Toner
# 1  {'Size:': ' 1000W', 'Style:': ' G2'}            Snake
# 2                                   NaN  Amazon Customer
# 3                                   NaN      Jeremy Bray
# 4                                   NaN             Mark
#
#                                           reviewText  \
# 0  my idea about product with id 'B006Z394GM' wit...
# 1  my idea about product with id 'B005BE058W' wit...
# 2  my idea about product with id 'B01DA0YCNC' wit...
# 3  my idea about product with id 'B00FBJ4KYC' wit...
# 4  my idea about product with id 'B00P7G82TS' wit...
#
#                                              summary  unixReviewTime  \
# 0  the prize for most useless invention of all ti...      1528070400
# 1                             melted molex connector      1518912000
# 2                             bricked on the regular      1516406400
# 3                                      do not buy!!!      1529884800
# 4                                nightmare  dont buy      1471392000
#
#                                                title                   brand
# 0  Silverstone Tek External Slim Optical Drive En...  SilverStone Technology
# 1  EVGA Supernova 750 G3, 80 Plus Gold 750W, Full...                    EVGA
# 2  Roku Streaming Stick (3600R) - HD Streaming Pl...                    Roku
# 3  SquareTrade 4-Year Home Security Protection Pl...             SquareTrade
# 4  Pumpkin Android 4.4.4 KitKat Car DVD Player 6....                 PUMPKIN

# %%
import shutil

test_data_spell_checked.to_csv('test_data_clean.csv')
shutil.move('/content/test_data_clean.csv', f'{folder_path}/test_data_clean.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/test_data_clean.csv'

# %%
test_data_clean_path = f'{folder_path}/test_data_clean.csv'
test_data_clean = pd.read_csv(test_data_clean_path)
test_data_clean.drop('Unnamed: 0', axis=1, inplace=True)

# %%
x_test = test_data_clean['reviewText']
x_test.shape
# Out:
# (20381,)

# %%
x_test.head()
# Out:
# 0    my idea about product with id 'B006Z394GM' wit...
# 1    my idea about product with id 'B005BE058W' wit...
# 2    my idea about product with id 'B01DA0YCNC' wit...
# 3    my idea about product with id 'B00FBJ4KYC' wit...
# 4    my idea about product with id 'B00P7G82TS' wit...
# Name: reviewText, dtype: object

# %% [markdown]
# ### Deviding Train data to Train and Validation

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train,
    y_train,
    test_size=0.2,
    shuffle=True,
    random_state=42
)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
#
#
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884

# %%
x_train_encoded = tokenizer.batch_encode_plus(
    x_train.tolist(),
    padding=True,
    truncation=True,
    max_length=128,
    return_tensors='tf'
)

# %%
x_val_encoded = tokenizer.batch_encode_plus(
    x_val.tolist(),
    padding=True,
    truncation=True,
    max_length=128,
    return_tensors='tf'
)

# %%
x_test_encoded = tokenizer.batch_encode_plus(
    x_test.tolist(),
    padding=True,
    truncation=True,
    max_length=128,
    return_tensors='tf'
)

# %% [markdown]
# ### Saving encodings in pickle files

# %%
import pickle

with open('train_encodings.pkl', 'wb') as file:
    pickle.dump(x_train_encoded, file)

with open('validation_encodings.pkl', 'wb') as file:
    pickle.dump(x_val_encoded, file)

with open('test_encodings.pkl', 'wb') as file:
    pickle.dump(x_test_encoded, file)

# %%
shutil.move('/content/train_encodings.pkl', '/content/drive/MyDrive/bootcamp/data/train_encodings.pkl')
shutil.move('/content/validation_encodings.pkl', '/content/drive/MyDrive/bootcamp/data/validation_encodings.pkl')
shutil.move('/content/test_encodings.pkl', '/content/drive/MyDrive/bootcamp/data/test_encodings.pkl')
# Out:
# '/content/drive/MyDrive/bootcamp/data/test_encodings.pkl'

# %% [markdown]
# ### Loading encodings from pickles

# %%
x_train_encoded = None
x_val_encoded = None
x_test_encoded = None

with open('/content/drive/MyDrive/bootcamp/data/train_encodings.pkl', 'rb') as file:
    x_train_encoded = pickle.load(file)

with open('/content/drive/MyDrive/bootcamp/data/validation_encodings.pkl', 'rb') as file:
    x_val_encoded = pickle.load(file)

with open('/content/drive/MyDrive/bootcamp/data/test_encodings.pkl', 'rb') as file:
    x_test_encoded = pickle.load(file)

# %%
model = TFBertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=5)
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.summary()
# Out:
# Model: "tf_bert_for_sequence_classification_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  109482240
#
#  dropout_75 (Dropout)        multiple                  0 (unused)
#
#  classifier (Dense)          multiple                  3845
#
# =================================================================
# Total params: 109486085 (417.66 MB)
# Trainable params: 109486085 (417.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
if tf.config.list_physical_devices('GPU'):
    with tf.device('/GPU:0'):
        model = model  # Just to clarify, this doesn't actually change the model
else:
    print("Using CPU")

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy('accuracy')]
)

# %%
history = model.fit(
    [x_train_encoded['input_ids'], x_train_encoded['token_type_ids'], x_train_encoded['attention_mask']],
    y_train,
    validation_data=(
        [x_val_encoded['input_ids'], x_val_encoded['token_type_ids'], x_val_encoded['attention_mask']],
        y_val
    ),
    batch_size=64,
    epochs=1
)
# Out:
# 2140/2140 [==============================] - 3753s 2s/step - loss: 1.3130 - accuracy: 0.5493 - val_loss: 1.2827 - val_accuracy: 0.5520

# %% [markdown]
# ### Saving Model and predicting final output

# %%
model.save_weights('model_weights_epoch1.h5')
shutil.copy('/content/model_weights_epoch1.h5', '/content/drive/MyDrive/bootcamp/data/model_weights_epoch1.h5')
# Out:
# '/content/drive/MyDrive/bootcamp/data/model_weights_epoch1.h5'

# %%
model.load_weights('model_weights_epoch1.h5')

# %%
train_loss, train_accuracy = model.evaluate(
    [x_train_encoded['input_ids'], x_train_encoded['token_type_ids'], x_train_encoded['attention_mask']],
    y_train
)

# %%
pred = model.predict(
    [x_test_encoded['input_ids'], x_test_encoded['token_type_ids'], x_test_encoded['attention_mask']]
)
# Out:
# 637/637 [==============================] - 174s 272ms/step

# %%
logits = pred.logits
predicted_scores = tf.argmax(logits, axis=1)
pred_labels = predicted_scores.numpy()
# Out:
# (4, 4)

# %% [markdown]
# ### Preparing and cleaning larger sample of train dataset

# %%
train_data['overall'].value_counts()
# Out:
# overall
# 5    461485
# 4    156514
# 1     82950
# 3     81239
# 2     56756
# Name: count, dtype: int64

# %%
train_data_larger_sample = train_data.sample(frac=0.5)
train_data_larger_sample['overall'].value_counts()
# Out:
# overall
# 5    230764
# 4     78186
# 1     41555
# 3     40723
# 2     28244
# Name: count, dtype: int64

# %%
train_data_larger_sample.shape
# Out:
# (419472, 11)

# %%
train_data_larger_sample['reviewText'] = train_data_larger_sample['reviewText'].apply(remove_stop_words)

# %%
train_data_larger_sample['reviewText'].head()
# Out:
# 27364     terrible very quiet muted installed rears 94 r...
# 250665    case is sturdy doesnt hold tablet securely . c...
# 310395    had speck 6 years so i really didnt want pay h...
# 775174    is review plr optics 52mm lens hood . first so...
# 405076    does i want do . sleek great hd quality . very...
# Name: reviewText, dtype: object

# %%
train_data_larger_sample['reviewText'] = train_data_larger_sample['reviewText'].apply(correct_spelling_symspell)

# %%
train_data_larger_sample = train_data_larger_sample.merge(title_brand, on='asin', how='inner')
train_data_larger_sample.head()
# Out:
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0        3  NaN      True  2016-04-05   ASITMQXEJ6Z5H  B000P0PF96
# 1        4  NaN      True  2016-02-09   AO8R2LK91PA4W  B00I3ERXWS
# 2        4  NaN      True  2016-08-25  A1MOB7OLXKPCER  B00M3WQJ80
# 3        4  NaN      True  2016-06-12   AFI21GZLOTSG2  B00GB2Z8IU
# 4        5  NaN      True  2016-09-23  A1O9AVUUJOOKZ0  B00TJQX9D6
#
#                                               style       reviewerName  \
# 0  {'Package Type:': ' Frustration-Free Packaging'}           P. Meyer
# 1                                               NaN          MARISSA G
# 2         {'Color:': ' Beautiful Phoenix Feathers'}  A P in Radford VA
# 3                                               NaN          Shaunessy
# 4                                               NaN               Ivan
#
#                                           reviewText  \
# 0  terrible very quiet muted installed rears of r...
# 1  case is sturdy doesn't hold tablet securely a ...
# 2  had speck a years so i really didst want pay h...
# 3  is review per optics comm lens hood a first so...
# 4  does i want do a sleek great he quality a very...
#
#                                              summary  unixReviewTime  \
# 0       inefficient muted no freq resp  install prob      1459814400
# 1                  sturdy but holds tablet too loose      1454976000
# 2  well forth the protections of your macbook pro...      1472083200
# 3                  worked on my dslr lens just fine.      1465689600
# 4               its sleek and its a great hd quality      1474588800
#
#                                                title       brand
# 0  Polk Audio DB571 5-by-7-Inch Coaxial Speakers ...  Polk Audio
# 1  Logitech Pro Protective Case with Full-Size Ke...    Logitech
# 2  DHZ Unique Ultra Thin Durable Keyboard Cover S...         DHZ
# 3  PLR Optics 52MM Lens Hood For The Panasonic Lu...         PLR
# 4   HP Pavilion 22xw 21.5-in IPS LED Backlit Monitor          HP

# %%
train_data_larger_sample['reviewText'] = train_data_larger_sample.apply(embed_product_info_in_comment, axis=1)
train_data_larger_sample.head()
# Out:
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0        3  NaN      True  2016-04-05   ASITMQXEJ6Z5H  B000P0PF96
# 1        4  NaN      True  2016-02-09   AO8R2LK91PA4W  B00I3ERXWS
# 2        4  NaN      True  2016-08-25  A1MOB7OLXKPCER  B00M3WQJ80
# 3        4  NaN      True  2016-06-12   AFI21GZLOTSG2  B00GB2Z8IU
# 4        5  NaN      True  2016-09-23  A1O9AVUUJOOKZ0  B00TJQX9D6
#
#                                               style       reviewerName  \
# 0  {'Package Type:': ' Frustration-Free Packaging'}           P. Meyer
# 1                                               NaN          MARISSA G
# 2         {'Color:': ' Beautiful Phoenix Feathers'}  A P in Radford VA
# 3                                               NaN          Shaunessy
# 4                                               NaN               Ivan
#
#                                           reviewText  \
# 0  my idea about product with id 'B000P0PF96' wit...
# 1  my idea about product with id 'B00I3ERXWS' wit...
# 2  my idea about product with id 'B00M3WQJ80' wit...
# 3  my idea about product with id 'B00GB2Z8IU' wit...
# 4  my idea about product with id 'B00TJQX9D6' wit...
#
#                                              summary  unixReviewTime  \
# 0       inefficient muted no freq resp  install prob      1459814400
# 1                  sturdy but holds tablet too loose      1454976000
# 2  well forth the protections of your macbook pro...      1472083200
# 3                  worked on my dslr lens just fine.      1465689600
# 4               its sleek and its a great hd quality      1474588800
#
#                                                title       brand
# 0  Polk Audio DB571 5-by-7-Inch Coaxial Speakers ...  Polk Audio
# 1  Logitech Pro Protective Case with Full-Size Ke...    Logitech
# 2  DHZ Unique Ultra Thin Durable Keyboard Cover S...         DHZ
# 3  PLR Optics 52MM Lens Hood For The Panasonic Lu...         PLR
# 4   HP Pavilion 22xw 21.5-in IPS LED Backlit Monitor          HP

# %%
train_data_larger_sample.to_csv('train_data_larger_sample.csv', index=False)
shutil.move('/content/train_data_larger_sample.csv', f'{folder_path}/train_data_larger_sample.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_larger_sample.csv'

# %% [markdown]
# ### Reduce train sample to balance and smaller one

# %%
train_data_larger_sample = pd.read_csv(f'{folder_path}/train_data_larger_sample.csv')
train_data_larger_sample.head()
# Out:
# <ipython-input-11-2be146e8e01b>:1: DtypeWarning:
#
# Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#    overall vote  verified  reviewTime      reviewerID        asin  \
# 0        3  NaN      True  2016-04-05   ASITMQXEJ6Z5H  B000P0PF96
# 1        4  NaN      True  2016-02-09   AO8R2LK91PA4W  B00I3ERXWS
# 2        4  NaN      True  2016-08-25  A1MOB7OLXKPCER  B00M3WQJ80
# 3        4  NaN      True  2016-06-12   AFI21GZLOTSG2  B00GB2Z8IU
# 4        5  NaN      True  2016-09-23  A1O9AVUUJOOKZ0  B00TJQX9D6
#
#                                               style       reviewerName  \
# 0  {'Package Type:': ' Frustration-Free Packaging'}           P. Meyer
# 1                                               NaN          MARISSA G
# 2         {'Color:': ' Beautiful Phoenix Feathers'}  A P in Radford VA
# 3                                               NaN          Shaunessy
# 4                                               NaN               Ivan
#
#                                           reviewText  \
# 0  my idea about product with id 'B000P0PF96' wit...
# 1  my idea about product with id 'B00I3ERXWS' wit...
# 2  my idea about product with id 'B00M3WQJ80' wit...
# 3  my idea about product with id 'B00GB2Z8IU' wit...
# 4  my idea about product with id 'B00TJQX9D6' wit...
#
#                                              summary  unixReviewTime  \
# 0       inefficient muted no freq resp  install prob      1459814400
# 1                  sturdy but holds tablet too loose      1454976000
# 2  well forth the protections of your macbook pro...      1472083200
# 3                  worked on my dslr lens just fine.      1465689600
# 4               its sleek and its a great hd quality      1474588800
#
#                                                title       brand
# 0  Polk Audio DB571 5-by-7-Inch Coaxial Speakers ...  Polk Audio
# 1  Logitech Pro Protective Case with Full-Size Ke...    Logitech
# 2  DHZ Unique Ultra Thin Durable Keyboard Cover S...         DHZ
# 3  PLR Optics 52MM Lens Hood For The Panasonic Lu...         PLR
# 4   HP Pavilion 22xw 21.5-in IPS LED Backlit Monitor          HP

# %%
train_data_larger_sample['overall'].value_counts()
# Out:
# overall
# 5    235695
# 4     79582
# 1     42272
# 3     41503
# 2     28741
# Name: count, dtype: int64

# %%
sample_per_class = 20000

samples = []
for i in range(1, 6):
    samples.append(train_data_larger_sample[train_data_larger_sample['overall'] == i].sample(20000))

train_data_balance = pd.concat(samples)

# %%
train_data_balance.head()
# Out:
#         overall vote  verified  reviewTime      reviewerID        asin  \
# 68052         1  NaN      True  2016-01-17  A35ILABSWNPC4C  B00IYETYX8
# 116446        1  NaN      True  2017-11-06  A1YJTMTDMJIGMV  B01CAFHOAG
# 348780        1  NaN      True  2018-09-21  A187G6GD6Q9AVA  B01GUITK24
# 140447        1  3.0      True  2016-09-09  A2YTYZ0YETAIZ1  B018WFMU84
# 194931        1  7.0      True  2016-03-15   AD2J9T115NCKI  B000Y92B2W
#
#                                             style reviewerName  \
# 68052                                         NaN      Chris R
# 116446                                        NaN        H. H.
# 348780  {'Style:': ' SONOS Play 5 Speaker Mount'}       Jack B
# 140447                                        NaN  Solsticeman
# 194931                                        NaN       Tony B
#
#                                                reviewText  \
# 68052   my idea about product with id 'B00IYETYX8' wit...
# 116446  my idea about product with id 'B01CAFHOAG' wit...
# 348780  my idea about product with id 'B01GUITK24' wit...
# 140447  my idea about product with id 'B018WFMU84' wit...
# 194931  my idea about product with id 'B000Y92B2W' wit...
#
#                                                  summary  unixReviewTime  \
# 68052               its a good thing this thing is cheap      1452988800
# 116446  the pictures show l1l2 r1r2 but they cant be ...      1509926400
# 348780                               very unsecure mount      1537488000
# 140447                                   too many issues      1473379200
# 194931                   eyepiece is not a nikon product      1458000000
#
#                                                     title       brand
# 68052   Mediasonic Homeworx HW180STB 3 / 4 Channel HDT...  Mediasonic
# 116446  Wireless Bluetooth VR Remote Controller Gamepa...     Loietnt
# 348780  WALI Dual Side Clamping Bookshelf Speaker Wall...        WALI
# 140447           Yuneec Typhoon Actioncam 4K Video Camera      Yuneec
# 194931               Nikon DK23 Rubber Eyecup Replacement       Nikon

# %%
train_data_balance['overall'].value_counts()
# Out:
# overall
# 1    20000
# 2    20000
# 3    20000
# 4    20000
# 5    20000
# Name: count, dtype: int64

# %%
train_data_balance.to_csv('train_data_balance.csv', index=False)
shutil.move('/content/train_data_balance.csv', f'{folder_path}/train_data_balance.csv')
# Out:
# '/content/drive/MyDrive/bootcamp/data/train_data_balance.csv'

# %%
train_data_balance.shape
# Out:
# (100000, 13)
